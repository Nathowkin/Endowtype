# %% [markdown]
# * How to load TCGA COAD
# * Notice: the file paths.py of Meow has been modified
# * Nathan Noiry, 10/05/2023

# %%
! pip install loguru
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.0/60.0 kB 6.0 MB/s eta 0:00:00
# ...

# %%
import os
import pandas as pd

from load import load_labels, load_clinical, load_project_meta, load_rnaseq, load_histo, load_metadata
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 4
#       1 import os
#       2 import pandas as pd
# ----> 4 from load import load_labels, load_clinical, load_project_meta, load_rnaseq, load_histo, load_metadata
#
# ModuleNotFoundError: No module named 'load'

# %%
cohort = "COAD"
#df_meta = load_metadata(cohort)
#df_labels = load_labels(cohort)
df_clin = load_clinical(cohort)
df_rnaseq = load_rnaseq(cohort)
df_histo = load_histo(cohort, "moco")

# %%
df_rnaseq.head()
# Out:
# Hugo          5_8S_rRNA    5S_rRNA        7SK       A1BG   A1BG-AS1
# patient_id
# TCGA-G4-6317  10.250526  10.325149  15.651656  12.191713  11.673502  \
# TCGA-G4-6322  10.250526  10.250526  13.105208  12.468946  12.557677
# TCGA-G4-6303  10.250526  10.250526  12.352328  12.115900  12.187654
# TCGA-G4-6299  10.250526  10.250526  13.166398  12.877503  12.909297
# TCGA-D5-6532  10.250526  10.250526  12.178849  11.683267  12.177282
#
# Hugo               A1CF        A2M    A2M-AS1      A2ML1  A2ML1-AS1  ...
# patient_id                                                           ...
# TCGA-G4-6317  16.072002  18.961887  14.185065  10.508708  10.745933  ...  \
# TCGA-G4-6322  15.899257  19.709976  14.623235  10.547626  10.585290  ...
# TCGA-G4-6303  16.458416  19.778669  14.075891  11.193395  10.894902  ...
# TCGA-G4-6299  14.045218  19.304182  14.578547  16.938742  10.700134  ...
# TCGA-D5-6532  17.211275  18.223438  13.355037  10.829152  10.434879  ...
#
# ...
